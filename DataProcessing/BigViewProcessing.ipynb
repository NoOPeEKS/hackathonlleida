# %% [markdown]
# Aquest codi serveix com a exemple i visualització pel seu posterior us a la nostra web aplication que usa django

# %%
import pandas as pd
import json
from itertools import chain
from collections import ChainMap

# %% [markdown]
# Obrim un json de resposta de l'api d'inteligence

# %%
with open('response.json') as f:
    data_dict = json.load(f)

# %% [markdown]
# Extraiem la part que ens interessa mostrar, els comparables

# %%
data_list = data_dict['response']['comparables']

# %% [markdown]
# Preparem un diccionari amb llistes de cada atribut per facilitar despres la neteja i preparar el dataframe

# %%
grouped_dict = {}
[grouped_dict.setdefault(key, []).append(value) for d in data_list for key, value in d.items()]
print(grouped_dict)
# Out:
# {'characteristics': [{'lot_size': 7536}, {'lot_size': 8625}, {'lot_size': 7710}, {'lot_size': 7623}, {'lot_size': 7623}, {'lot_size': 7275}, {'lot_size': 6821}, {'lot_size': 10672}, {'lot_size': 6882}, {'lot_size': 6447}, {'lot_size': 7841}, {'lot_size': 9670}, {'lot_size': 7797}, {'lot_size': 7318}, {'lot_size': 7275}, {'lot_size': 8015}, {'lot_size': 7536}, {'lot_size': 8538}, {'lot_size': 7362}, {'lot_size': 7057}, {'lot_size': 7275}, {'lot_size': 6403}, {'lot_size': 5924}, {'lot_size': 7667}, {'lot_size': 7532}, {'lot_size': 8756}, {'lot_size': 7405}, {'lot_size': 7492}, {'lot_size': 8756}, {'lot_size': 7710}, {'lot_size': 7362}, {'lot_size': 9714}, {'lot_size': 6621}, {'lot_size': 6186}, {'lot_size': 7579}, {'lot_size': 7710}, {'lot_size': 7231}, {'lot_size': 6229}, {'lot_size': 9104}, {'lot_size': 5358}], 'image_data': [{'r1r6': {'bathroom': 3.1, 'exterior': 3.7, 'interior': 2.5, 'kitchen': 2.7, 'property': 3}}, {'r1r6': {'bathroom': 2.9, 'exterior': 3.9, 'interior': 3.1, 'kitc
# ...

# %% [markdown]
# Ara agrupem els elements per posició i eliminem els elements que no ens interessen

# %%
ordered_dict = {}
for key, value in grouped_dict.items():
    for i, inner_dict in enumerate(value):
        if key == 'media':
            continue
        ordered_dict.setdefault(i, []).append(inner_dict)

# %% [markdown]
# Ara desfem els diccionaris petits i ho posem tot en un diccionari gran

# %%
final_dict = {}
for key, value in ordered_dict.items():
    final_dict[key] = dict(ChainMap(*value))

# %% [markdown]
# Finalment creem el dataframe i el trasposem per deixar les columnes con les volem

# %%
df = pd.DataFrame.from_dict(final_dict).T

# %%
df
# Out:
#    bathrooms_full bathrooms_half bedrooms_total garage_spaces living_area  \
# 0               2              0              3             0        1246
# 1               1              0              2             1        1078
# 2               2              0              3             0        1164
# 3               2              0              4             2        1312
# 4               2              0              4             2        1278
# 5               2              0              3             0        1236
# 6               2              0              4             0        1268
# 7               1              0              3             1         912
# 8               1              0              3             1         936
# 9               1              0              3             0        1151
# 10              2              0              3             1        1268
# 11              2              1              3             0        1276
# ...
