# %% [markdown]
# ## Obtenció de les URL

# %%
import torch
import torchvision
from torch import nn
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt

# %%
data = pd.read_json('train.json')
data.rename(columns={'photos': 'Url'}, inplace=True)

# %%
data
# Out:
#         bathrooms  bedrooms                       building_id  \
# 4             1.0         1  8579a0b0d54db803821a35a4a615e97a
# 6             1.0         2  b8e75fc949a6cd8225b455648a951712
# 9             1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 10            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 15            1.0         0  bfb9405149bfff42a92980b594c28234
# ...           ...       ...                               ...
# 124000        1.0         3  92bbbf38baadfde0576fc496bd41749c
# 124002        1.0         2  5565db9b7cba3603834c4aa6f2950960
# 124004        1.0         1  67997a128056ee1ed7d046bbb856e3c7
# 124008        1.0         2  3c0574a740154806c18bdf1fddd3d966
# 124009        1.0         3  d89f514c3ed0abaae52cba7017ac0701
#
#                     created  \
# 4       2016-06-16 05:55:27
# 6       2016-06-01 05:44:33
# 9       2016-06-14 15:19:59
# 10      2016-06-24 07:54:24
# 15      2016-06-28 03:50:23
# ...                     ...
# ...

# %%
dt=data.Url
dt
# Out:
# 4         [https://photos.renthop.com/2/7170325_3bb5ac84...
# 6         [https://photos.renthop.com/2/7092344_7663c19a...
# 9         [https://photos.renthop.com/2/7158677_c897a134...
# 10        [https://photos.renthop.com/2/7211212_1ed4542e...
# 15        [https://photos.renthop.com/2/7225292_901f1984...
#                                 ...
# 124000    [https://photos.renthop.com/2/6824800_0682be16...
# 124002    [https://photos.renthop.com/2/6813268_1e6fcc32...
# 124004    [https://photos.renthop.com/2/6927093_93a52104...
# 124008    [https://photos.renthop.com/2/6892816_1a8d087a...
# 124009    [https://photos.renthop.com/2/6901023_02052d90...
# Name: Url, Length: 49352, dtype: object

# %%
url=dt.explode().reset_index(drop=True)
url
# Out:
# 0         https://photos.renthop.com/2/7170325_3bb5ac84a...
# 1         https://photos.renthop.com/2/7170325_a29a17a77...
# 2         https://photos.renthop.com/2/7170325_149a898e8...
# 3         https://photos.renthop.com/2/7170325_f74a43d78...
# 4         https://photos.renthop.com/2/7170325_e677d9d24...
#                                 ...
# 280324    https://photos.renthop.com/2/6901023_c6071d1b2...
# 280325    https://photos.renthop.com/2/6901023_8caf0fe76...
# 280326    https://photos.renthop.com/2/6901023_17a0bbcac...
# 280327    https://photos.renthop.com/2/6901023_489b361b0...
# 280328    https://photos.renthop.com/2/6901023_f9a930898...
# Name: Url, Length: 280329, dtype: object

# %%
url.to_csv('urls.csv')

# %%
import pandas as pd

# Suposem que 'df' és el teu DataFrame original amb una columna que conté llistes o conjunts de valors
# Aplicar explode a la columna específica
df_exploded = df.explode('nom_de_la_columna')  # Replace 'nom_de_la_columna' amb el nom real de la teva columna

# Guardar el DataFrame resultant amb explode en un fitxer CSV
fitxer_csv = 'fitxer_exploded.csv'  # Nom del fitxer CSV
df_exploded.to_csv(fitxer_csv, index=False)  # Guardar sense índex de fila
